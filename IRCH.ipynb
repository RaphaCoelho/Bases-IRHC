# %%
import pandas as pd
import numpy as np
import datetime as dt

# %%
rhc12 = pd.read_excel('C:\\Users\\raphael.coelho\\PythonP\\Bases-IRHC\\rhc12.xlsx')
rhc13 = pd.read_excel('C:\\Users\\raphael.coelho\\PythonP\\Bases-IRHC\\rhc13.xlsx')
rhc14 = pd.read_excel('C:\\Users\\raphael.coelho\\PythonP\\Bases-IRHC\\rhc14.xlsx')
rhc15 = pd.read_excel('C:\\Users\\raphael.coelho\\PythonP\\Bases-IRHC\\rhc15.xlsx')
rhc16 = pd.read_excel('C:\\Users\\raphael.coelho\\PythonP\\Bases-IRHC\\rhc16.xlsx')
rhc17 = pd.read_excel('C:\\Users\\raphael.coelho\\PythonP\\Bases-IRHC\\rhc17.xlsx')


bases = [rhc12,rhc13,rhc14,rhc15,rhc16,rhc17]

# %%
for base in bases:
    base ['SEXO'] = base ['SEXO'].map( {1: 'Masculino', 
                                        2: 'Feminino' }).astype(str)

# %%
for base in bases:
    base['RACA_COR'] = base['RACA_COR'].map( {1: 'Branca', 
                                              2: 'Preta', 
                                              3: 'Amarela', 
                                              4: 'Parda', 
                                              5: 'Indígena', 
                                              9: 'Sem informação'}).astype(str)

# %%
for base in bases:
    base['ESCOLARIDADE'] = base['ESCOLARIDADE'].map( {1: 'Nenhuma', 
                                                      2: 'Fundamental incompleto', 
                                                      3: 'Fundamental completo', 
                                                      4: 'Nível médio', 
                                                      5: 'Nível superior incompleto', 
                                                      6: 'Nível superior completo', 
                                                      9: 'Sem informação' }).astype(str)

# %%
for base in bases:
    base['HIST_FAMILIAR'] = base['HIST_FAMILIAR'].map( {1: 'Sim', 
                                                        2: 'Não', 
                                                        9: 'Sem informação'}).astype(str)

# %%
for base in bases:
    base['ETILISMO'] = base['ETILISMO'].map( {1: 'Não', 
                                              2: 'Ex-consumidor', 
                                              3: 'Sim', 
                                              4: 'Não', 
                                              8: 'Não se Aplica', 
                                              9: 'Sem Informação'} ).astype(str)

# %%
for base in bases:
    base['TABAGISMO'] = base['TABAGISMO'].map( {1: 'Não',
                                                2: 'Ex-consumidor', 
                                                3: 'Sim', 
                                                4: 'Não avaliado', 
                                                8: 'Não se aplica', 
                                                9: 'Sem informação'}).astype(str)

# %%
for base in bases:
    base['CIDADE_PROCED'] = base['CIDADE_PROCED'].map( {3304557: 'Rio de Janeiro',
                                                                  3300902: 'Cambuci', 
                                                                  3300456: 'Belford Roxo', 
                                                                  3303500: 'Nova Iguaçu', 
                                                                  3302270: 'Japeri',
                                                                  3303401: 'Nova Friburgo', 
                                                                  3301702: 'Duque de Caxias', 
                                                                  3304300: 'Rio Bonito', 
                                                                  3305752: 'Tanguá', 
                                                                  3305802: 'Teresópolis', 
                                                                  3301009: 'Campos dos Goytacazes', 
                                                                  3305109: 'São João de Meriti', 
                                                                  3302007: 'Itaguaí',  
                                                                  3300407: 'Barra Mansa', 
                                                                  3303203: 'Nilópolis',
                                                                  3304805: 'São Fidélis',
                                                                  3300506: 'Bom Jardim',
                                                                  3302858: 'Mesquita',
                                                                  3304904: 'São Gonçalo',
                                                                  3303906: 'Petrópolis',
                                                                  3302502: 'Magé', 
                                                                  3305505: 'Saquarema',
                                                                  3301900: 'Itaboraí', 
                                                                  3300605: 'Bom Jesus do Itabapoana',
                                                                  3303005: 'Miracema', 
                                                                  3300225: 'Areal',
                                                                  3304144: 'Queimados',
                                                                  3304003: 'Piraí', 
                                                                  3301306: 'Casimiro de Abreu', 
                                                                  3304110: 'Porto Real',
                                                                  3304524: 'Rio das Ostras',
                                                                  3301850: 'Guapimirim',
                                                                  3301876: 'Iguaba Grande',
                                                                  3305703: 'Sumidouro',
                                                                  3302601: 'Mangaratiba', 
                                                                  3302700: 'Maricá',
                                                                  3300100: 'Angra dos Reis',
                                                                  3304755: 'São Francisco de Itabapoana',
                                                                  3303302: 'Niterói', 
                                                                  3300803: 'Cachoeiras de Macacu',
                                                                  3305604: 'Silva Jardim',
                                                                  3300704: 'Cabo Frio',
                                                                  3302403: 'Macaé',
                                                                  3306008: 'Três Rios', 
                                                                  3304201: 'Resende', 
                                                                  3304151: 'Quissamã', 
                                                                  3300209: 'Araruama', 
                                                                  3301157: 'Cardoso Moreira', 
                                                                  3304102: 'Porciúncula',
                                                                  3302056: 'Italva', 
                                                                  3115508: 'Caxambu', 
                                                                  3301207: 'Carmo', 
                                                                  3306206: 'Vassouras', 
                                                                  3303807: 'Paraty', 
                                                                  3306305: 'Volta Redonda', 
                                                                  3304409: 'Rio Claro',
                                                                  3301108: 'Cantagalo', 
                                                                  3301405: 'Conceição de Macabu', 
                                                                  3302304: 'Laje do Muriaé', 
                                                                  3303856: 'Paty do Alferes', 
                                                                  3300936: 'Carapebus', 
                                                                  3302254: 'Itatiaia', 
                                                                  3302106: 'Itaocara',
                                                                  3305554: 'Seropédica', 
                                                                  3305208: 'São Pedro da Aldeia', 
                                                                  3304706: 'Santo Antônio de Pádua', 
                                                                  3300258: 'Arraial do Cabo', 
                                                                  3306107: 'Valença', 
                                                                  3303104: 'Natividade', 
                                                                  3302205: 'Itaperuna',
                                                                  3302908: 'Miguel Pereira', 
                                                                  3300308: 'Barra do Piraí', 
                                                                  3509502: 'Campinas', 
                                                                  3300233: 'Armação dos Búzios', 
                                                                  3305000: 'São João da Barra', 
                                                                  3303609: 'Paracambi', 
                                                                  3303708: 'Paraíba do Sul',
                                                                  3305406: 'Scapucaia', 
                                                                  3305307: 'São Sebastião do Alto', 
                                                                  3300159: 'Aperibé', 
                                                                  2611606: 'Recife', 
                                                                  3305158: 'São José do Vale do Rio Preto', 
                                                                  9999999: 'Sem Informação', 
                                                                  3303955: 'Pinheiral',
                                                                  3305133: 'São José de Ubá', 
                                                                  3306156: 'Varre-Sai', 
                                                                  3305901: 'Trajano de Moraes'}).astype(str)

# %%
for base in bases:
    base['ORIGEM_ENC'] = base['ORIGEM_ENC'].map( {1: 'SUS',
                                                  2: 'Privado', 
                                                  3:'Sem encaminhamento', 
                                                  8: 'Não se aplica', 
                                                  9: 'Sem informação'}).astype(str)

# %%
for base in bases:
    base['ESTADO_CIVIL'] = base['ESTADO_CIVIL'].map( {1: 'Solteiro',
                                                      2: 'Casado', 
                                                      3: 'Viúvo',
                                                      5: 'União consensual',
                                                      4: 'Divociardo', 
                                                      9: 'Sem informação'}).astype(str)

# %%
for base in bases:
    base['DIAG_TRAT_ANT'] = base['DIAG_TRAT_ANT'].map( {1: 'Sem diagnóstico/tratamento',
                                                      2: 'Com diagnóstico/sem tratamento', 
                                                      3: 'Com diagnóstico/tratamento', 
                                                      9: 'Sem informação'}).astype(str)

# %%
for base in bases:
    base['BAS_MAIS_IMP_DIAG'] = base['BAS_MAIS_IMP_DIAG'].map( {1: 'Clínica',
                                                          2: 'Pesquisa clínica', 
                                                          3: 'Exame por imagem', 
                                                          4: 'Marcadores tumorais', 
                                                          5: 'Citologia', 
                                                          6: 'Histologia por metástase',
                                                          7: 'Histologia do tumor primário', 
                                                          9: 'Sem informação'}).astype(str)

# %%
for base in bases:
    base['LOC_PRIMA_DET'] = base['LOC_PRIMA_DET'].map( {'C53.0': 'Endocérvice', 
                                                        'C53.1': 'Exocérvice', 
                                                        'C53.8': 'Lesão sobreposta do colo do útero', 
                                                        'C53.9': 'Colo do útero'}).astype(str)

# %%
for base in bases:
    base['MAIS_UM_TUMOR'] = base['MAIS_UM_TUMOR'].map( {1: 'Não', 
                                                        2: 'Sim', 
                                                        3: 'Suspeito',
                                                        0: 'Sem informação'}).astype(str)

# %%
for base in bases:
    base['TNM'] = base['TNM'].astype(str)
    base.TNM.replace(['0','888','999'], ['Sem informação', 'Sem informação',
                                     'Sem informação'], inplace=True)

# %%
for base in bases:
    base.ESTAD_CLÍNICO.replace(['0', '88', '99'], ['Sem informação', 'Sem informação',
                                                 'Sem informação'], inplace=True)

# %%
for base in bases:
    base.GRUPO_ESTAD.replace([0, 8, 9], ['Sem informação', 'Sem informação',
                                                 'Sem informação'] , inplace=True)

# %%
for base in bases:
    base ['RZNTR'] = base ['RZNTR'].map( {1: 'Recusa do tratamento', 
                                          2: 'Tratamento realizado em outro lugar', 
                                          3: 'Doença avançada, falta de condições clínicas ou outras comorbidades', 
                                          4: 'Abandono do tratamento', 
                                          5: 'Eventos adversos ao tratamento', 
                                          6: 'Óbito', 
                                          7: 'Outras razões', 
                                          8: 'Não se aplica', 
                                          9: 'Sem informação' }).astype(str)

# %%
for base in bases:
    base ['PRIMA_TRAT_HOSP'] = base ['PRIMA_TRAT_HOSP'].map( {1: 'Nenhum', 
                                                              2: 'Cirurgia', 
                                                              3: 'Radioterapia', 
                                                              4: 'Quimioterapia', 
                                                              5: 'Hormonioterapia', 
                                                              6: 'TMO', 
                                                              7: 'Imunoterapia', 
                                                              8: 'Outros', 
                                                              9: 'Sem informação', 
                                                              43: 'QT/RTX', 
                                                              34: 'RTX/QT', 
                                                              343: 'RTX/QT/RTX', 
                                                              33: 'RTX/RTX', 
                                                              234: 'Cirurgia/RTX/QT', 
                                                              2343: 'Cirurgia/RTX/QT/RTX', 
                                                              22: 'Cirurgia/Cirurgia', 
                                                              438: 'QT/RTX/Outros', 
                                                              23: 'Cirurgia/RTX', 
                                                              83: 'Outros/RTX', 
                                                              384: 'RTX/Outros/QT', 
                                                              24: 'Cirurgia/QT', 
                                                              42: 'QT/Cirurgia', 
                                                              84: 'Outros/QT', 
                                                              233: 'Cirurgia/RTX/RTX', 
                                                              45: 'QT/HT', 
                                                              44: 'QT/QT', 
                                                              38: 'RTX/Outros', 
                                                              3432: 'RTX/QT/RTX/Cirurgia', 
                                                              243: 'Cirurgia/QT/RTX', 
                                                              22343: 'Cirurgia/Cirurgia/RTX/QT/RTX',    
                                                              32: 'RTX/Cirurgia',
                                                              387: 'RTX/Outros/Imunoterapia',   
                                                              348: 'RTX/QT/Outros',   
                                                              344: 'RTX/QT/QT',  
                                                              3433: 'RTX/QT/RTX/RTX',   
                                                              342: 'RTX/QT/Cirurgia',   
                                                              433: 'QT/RTX/RTX',   
                                                              843: 'Outros/QT/RTX',   
                                                              345: 'RTX/QT/HT',
                                                              53: 'HT/RTX',  
                                                              2344: 'Cirurgia/RTX/QT/QT',   
                                                              432: 'QT/RTX/Cirurgia',  
                                                              2432: 'Cirurgia/QT/RTX/Cirurgia',   
                                                              222: 'Cirurgia/Cirurgia/Cirurgia',   
                                                              424: 'QT/Cirurgia/QT',   
                                                              223: 'Cirurgia/Cirurgia/RTX',   
                                                              834: 'Outros/RXT/QT',
                                                              48: 'QT/Outros',    
                                                              28: 'Cirurgia/Outros',   
                                                              324: 'RTX/Cirurgia/QT',    
                                                              58: 'HT/Outros',  
                                                              2435: 'Cirurgia/QT/RTX/HT',   
                                                              425: 'QT/Cirurgia/HT',  
                                                              2234: 'Cirurgia/Cirurgia/RTX/QT',   
                                                              224: 'Cirurgia/Cirurgia/QT',  
                                                              832: 'Outros/RTX/Cirurgia',
                                                              434: 'QT/RTX/QT',  
                                                              2438: 'Cirurgia/QT/RTX/Outros'   }).astype(str)

# %%
for base in bases:
    base ['DESF_PRIMA_TRAT'] = base ['DESF_PRIMA_TRAT'].map( {1: 'Remissão completa', 
                                                              2: 'Remissão parcial', 
                                                              3: 'Doença estável', 
                                                              4: 'Doença em progressão', 
                                                              5: 'Suporte terapêutico oncológico', 
                                                              6: 'Óbito', 
                                                              8: 'Não se aplica', 
                                                              9: 'Sem informação' }).astype(str)

# %%
for base in bases:
    base ['CNES'] = base ['CNES'].map( {2269988: 'Hospital dos Servidores do Estado', 
                                        2278855: 'Hospital São José do Avaí', 
                                        2269821: 'INCA 2', 
                                        2269384: 'Hospital do Andaraí', 
                                        2292386: 'Hospital São José - Associação da Congregação de Santa Catarina', 
                                        2287285: 'Hospital Geral Dr. Beda- Instituto de Medicina Nuclear e Endocrinologia', 
                                        2275562: 'Hospital Alcides Carneiro', 
                                        2268779: 'Centro de Terapia Oncológica SC LTDA', 
                                        2269880: 'Hospital Geral de Bonsucesso', 
                                        2287250: 'Sociedade Porturguesa de Beneficência de Campos',
                                        2287447: 'Hospital Universitário Álvaro Alvim', 
                                        12505: 'Hospital Universitário Antonio Pedro - UFF',
                                        2278286: 'Hospital Santa Isabel', 
                                        2280167: 'Hospital Universitário Clementino Fraga Filho - UFRJ', 
                                        25186: 'Hospital Jardim Amália LTDA - HINJA', 
                                        2269899: 'Hospital Mário Kroeff - Associação Brasileira de Assisência ao Câncer', 
                                        2296241: 'Hospital Regional Darcy Vargas', 
                                        2295423: 'Hospital Geral de Jacarepaguá - Hospital Cardoso Fontes'       }).astype(str)

# %%
for base in bases:
    base ['CIDADE_HOSPITAL'] = base ['CIDADE_HOSPITAL'].map( {3304557: 'Rio de Janeiro', 
                                                              3302205: 'Itaperuna', 
                                                              3305802: 'Teresópolis', 
                                                              3301009: 'Campos dos Goytacazes', 
                                                              3303906: 'Petrópolis', 
                                                              3303302: 'Niterói', 
                                                              3300704: 'Cabo Frio', 
                                                              3306305: 'Volta Redonda', 
                                                              3304300: 'Rio Bonito'}).astype(str)

# %%
for base in bases:
    base ['OCUPACAO'] = base ['OCUPACAO'].map( {451: 'Vendedora', 795: 'Costureira',  
                                                540: 'Empregada Doméstica', 999: 'Não Classificado', 
                                                552: 'Auxiliar de Seviços Gerais', 9999: 'Não Classificado', 
                                                570: 'Cabelereira', 394: 'Recepcionista', 
                                                149: 'Professora', 410: 'Comerciante', 
                                                531: 'Cozinheira',321: 'Secretária',  
                                                791: 'Costureira',142: 'Professora',   
                                                72: 'Técnica de Enfermagem',  888: 'Ourives',   
                                                30: 'Técnica de Contabilidade',  141: 'Professora',  
                                                452: 'Vendedora',  490: 'Trabalhadora de Comércio',  
                                                163: 'Fotógrafa',  621: 'Agricultora', 
                                                399: 'Auxiliar Administrativo',  572: 'Técnica de Laboratório',  
                                                985: 'Motorista',  311: 'Assistente Administrativo',   
                                                74: 'Psicológa',   29: 'Engenheira',  
                                                719: 'Mineradora',  314: 'Serventuária da Justiça',  
                                                249: 'Gerente de Empresas',   39: 'Técnica de Nível Médio',  
                                                339: 'Operadora de Caixa', 599: 'Guia Turístico',   
                                                71: 'Enfermeira',  799: 'Costureira',  
                                                332: 'Operadora de Caixa',  872: 'Soldadora',  
                                                393: 'Auxiliar de Escritório',  939: 'Pintora',  
                                                331: 'Operadora de Caixa', 79: 'Médica',  
                                                121: 'Adovagada', 560: 'Lavadeira', 
                                                131: 'Professora', 664: 'Pescadora',  
                                                198: 'Analista de Seguro', 92: 'Administradora de Empresas',  
                                                532: 'Garçonete',  341: 'Auxiliar de Contabilidade',  
                                                859: 'Eletricista',  214: 'Servidora Pública',   
                                                73: 'Assistente Social',  779: 'Auxiliar de Cozinha',  
                                                137: 'Professora', 241: 'Gerente Administrativo',  
                                                192: 'Socióloga',  639: 'Agricultora',  
                                                239: 'Diretora de Empresas',  174: 'Empresária',  
                                                989: 'Motorista', 68: 'Nutricionista',  
                                                749: 'Técnica de Química',  143: 'Professora',  
                                                931: 'Pintora',  136: 'Professora',
                                                67: 'Farmacêuitca',  175: 'Artista de Circo',  
                                                179: 'Musicista', 63: 'Cirurgiã-dentista',  
                                                380: 'Telefonista', 583: 'Segurança', 
                                                65: 'Médica Veterinária', 441: 'Corretora de Seguros',  
                                                144: 'Professora', 33: 'Técnica de Agrimensura',  
                                                669: 'Pescadora', 171: 'Cantora',  
                                                754: 'Tecelã',  835: 'Operadora de Máquinas',   
                                                93: 'Contadora',  432: 'Representante Comercial',  
                                                756: 'Tintureira',  959: 'Trabalhadora de Construção Cívil',  
                                                454: 'Decoradora', 61: 'Médica'}).astype(str)

# %%
for base in bases:   
    #base['IDADE'] = base['IDADE'].astype(str)
    base.loc[ base['IDADE'] <= 19, 'FAIXA_ETARIA'] = '0-19'
    base.loc[(base['IDADE'] >= 20) & (base['IDADE'] <= 39), 'FAIXA_ETARIA'] = '20-39'
    base.loc[(base['IDADE'] > 39) & (base['IDADE'] <= 64), 'FAIXA_ETARIA'] = '40-64'
    base.loc[base['IDADE'] >= 65, 'FAIXA_ETARIA'] = '>65'

# %%
L1 = ['RJ']
d1 = dict.fromkeys(L1, 'RJ')

L2 = ['MG', 'SP', 'PE']
d2 = dict.fromkeys(L2, 'Outros Estados')

L3 = ['99']
d3 = dict.fromkeys(L3, 'Sem Informação')

d = {**d1, **d2, **d3}
for base in bases:
    base['UF_PROCED2'] = base['UF_PROCED'].map(d)

# %%
L1 = ['Angra dos Reis', 'Paraty', 'Mangaratiba']
d1 = dict.fromkeys(L1, 'Baia de Ilha Grande')

L2 = ['Araruama', 'Armação dos Búzios', 'Arraial do Cabo', 'Cabo Frio', 'Casimiro de Abreu', 'Iguaba Grande', 
      'Rio das Ostras', 'São Pedro da Aldeia', 'Saquarema']
d2 = dict.fromkeys(L2, 'Baixada Litoranea')

L3 = ['Areal', 'Miguel Pereira', 'Paraíba do Sul', 'Paty do Alferes', 'Scapucaia', 'Três Rios', 'Vassouras', 
      'Paracambi']
d3 = dict.fromkeys(L3, 'Centro-sul')

L4 = ['Barra do Piraí','Barra Mansa', 'Itatiaia', 'Pinheiral', 'Piraí', 'Porto Real', 'Resende', 'Rio Claro', 
      'Valença', 'Volta Redonda']
d4 = dict.fromkeys(L4, 'Médio Paraíba')

L5 = ['Belford Roxo', 'Duque de Caxias', 'Itaguaí', 'Japeri', 'Magé', 'Mesquita', 'Nilópolis', 
       'Nova Iguaçu', 'Queimados', 'Rio de Janeiro', 'São João de Meriti', 'Seropédica']
d5 = dict.fromkeys(L5, 'Metropolitana I')

L6 = ['Itaboraí', 'Maricá', 'Niterói', 'São Gonçalo', 'Tanguá', 'Rio Bonito', 'Silva Jardim']
d6 = dict.fromkeys(L6, 'Metropolitana II')

L7 = ['Aperibé', 'Bom Jesus do Itabapoana', 'Cambuci', 'Italva', 'Itaocara', 'Itaperuna', 'Laje do Muriaé', 
      'Miracema', 'Natividade', 'Porciúncula', 'Santo Antônio de Pádua', 'São José de Ubá', 'Varre-Sai']
d7 = dict.fromkeys(L7, 'Noroeste')

L8 = ['Campos dos Goytacazes', 'Carapebus', 'Cardoso Moreira', 'Conceição de Macabu', 'Macaé', 'Quissamã', 
      'São Fidélis', 'São Francisco de Itabapoana', 'São João da Barra'] 
d8 = dict.fromkeys(L8, 'Norte')

L9 = ['Bom Jardim', 'Cantagalo', 'Carmo', 'Nova Friburgo', 'Petrópolis', 'São Sebastião do Alto', 
      'Sumidouro', 'Trajano de Moraes','Teresópolis', 'Cachoeiras de Macacu', 'Guapimirim', 
      'São José do Vale do Rio Preto']
d9 = dict.fromkeys(L9, "Serrana")

d = {**d1, **d2, **d3, **d4, **d5, **d6, **d7, **d8, **d9}
for base in bases:
    base['REGIAO_SAUDE'] = base['CIDADE_PROCED'].map(d)

# %%
database = pd.concat([rhc12,rhc13,rhc14,rhc15,rhc16,rhc17], sort=False)

# %%
database['DATA_OBITO'].replace({'/  /':'01/01/2100','99/99/9999':'01/01/1900'}, inplace=True)
database['DT_INICIO_TRAT'].replace({'/  /':'01/01/1900', '88/88/8888':'01/01/1900','99/99/9999':'01/01/1900'}, inplace=True)
database['DT_PRIMA_CONS'].replace({'/  /':'01/01/1900', '88/88/8888':'01/01/1900','99/99/9999':'01/01/1900'}, inplace=True)
database['DT_PRIMA_DIAG'].replace({'/  /':'01/01/1900', '88/88/8888':'01/01/1900','99/99/9999':'01/01/1900'}, inplace=True)

# %%
database['MES_DIAG'] = pd.DatetimeIndex(database['DT_PRIMA_DIAG']).month
database['MES_CONS'] = pd.DatetimeIndex(database['DT_PRIMA_CONS']).month
database['MES_TRAT'] = pd.DatetimeIndex(database['DT_INICIO_TRAT']).month
database['MES_OBITO'] = pd.DatetimeIndex(database['DATA_OBITO']).month

# %%
database['ANO_DIAG'] = pd.DatetimeIndex(database['DT_PRIMA_DIAG']).year
database['ANO_CONS'] = pd.DatetimeIndex(database['DT_PRIMA_CONS']).year
database['ANO_TRAT'] = pd.DatetimeIndex(database['DT_INICIO_TRAT']).year
database['ANO_OBITO'] = pd.DatetimeIndex(database['DATA_OBITO']).year

# %%
database ['PERIODO_CONS'] = database ['MES_CONS'].map( {1: '1º Bimestre', 
                                            2: '1º Bimestre',
                                            3: '2º Bimestre',
                                            4: '2º Bimestre',
                                            5: '3º Bimestre',
                                            6: '3º Bimestre',
                                            7: '4º Bimestre',
                                            8: '4º Bimestre',
                                            9: '5º Bimestre',
                                            10: '5º Bimestre',
                                            11: '6º Bimestre',
                                            12: '6º Bimestre',}).astype(str)

database ['PERIODO_DIAG'] = database ['MES_DIAG'].map( {1: '1º Bimestre', 
                                            2: '1º Bimestre',
                                            3: '2º Bimestre',
                                            4: '2º Bimestre',
                                            5: '3º Bimestre',
                                            6: '3º Bimestre',
                                            7: '4º Bimestre',
                                            8: '4º Bimestre',
                                            9: '5º Bimestre',
                                            10: '5º Bimestre',
                                            11: '6º Bimestre',
                                            12: '6º Bimestre',}).astype(str)

database ['PERIODO_TRAT'] = database ['MES_TRAT'].map( {1: '1º Bimestre', 
                                            2: '1º Bimestre',
                                            3: '2º Bimestre',
                                            4: '2º Bimestre',
                                            5: '3º Bimestre',
                                            6: '3º Bimestre',
                                            7: '4º Bimestre',
                                            8: '4º Bimestre',
                                            9: '5º Bimestre',
                                            10: '5º Bimestre',
                                            11: '6º Bimestre',
                                            12: '6º Bimestre',}).astype(str)

database ['PERIODO_OBITO'] = database ['MES_OBITO'].map( {1: '1º Bimestre', 
                                              2: '1º Bimestre',
                                              3: '2º Bimestre',
                                              4: '2º Bimestre',
                                              5: '3º Bimestre',
                                              6: '3º Bimestre',
                                              7: '4º Bimestre',
                                              8: '4º Bimestre',
                                              9: '5º Bimestre',
                                              10: '5º Bimestre',
                                              11: '6º Bimestre',
                                              12: '6º Bimestre',}).astype(str)

# %%
database['ANO_MES_BASE'] = database['ANO_CONS'].map(str) + '-' + database['MES_CONS'].map(str)
database['ANO_PERIODO_BASE'] = database['ANO_CONS'].map(str) + '-' + database['PERIODO_CONS'].map(str)

# %%
database.to_excel('C:\\Users\\raphael.coelho\\PythonP\\Bases-IRHC\\database_v6.xlsx')
