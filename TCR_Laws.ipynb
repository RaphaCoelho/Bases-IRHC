# %%
import pandas as pd

# %%
base = pd.read_excel("C:\\Users\\rapha\\Desktop\\Lara\\TCR\\Bases_TCR\\Bases_V7\\database_v7.xlsx", sheet_name="Sheet1")

# %%
base.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  TP_CASO      SEXO IDADE LOCAL_NASC RACA_COR  \
# 0           0             0        1  Feminino    50         RJ    Parda
# 1           1             1        1  Feminino    76         MA   Branca
# 2           2             2        1  Feminino    39         RJ   Branca
# 3           3             3        1  Feminino    58         RJ    Preta
# 4           4             4        1  Feminino    44         RN    Parda
#
#              ESCOLARIDADE  CLIN_1_ATEND  CLIN_INICIO_TRAT  ... PERIODO_TRAT  \
# 0    Fundamental completo            15                25  ...            8
# 1  Fundamental incompleto            15                24  ...            4
# 2          Sem informação            15                15  ...           11
# 3          Sem informação            15                15  ...            2
# 4  Fundamental incompleto            15                15  ...            7
#
#   PERIODO_OBITO   ANO STATUS_DESF                 PRIMA_TRAT2  \
# ...

# %%
base.loc[ base['TRAT-DIAG'] <= 60, 'LEI60'] = 'Tempo adequado'
base.loc[base['TRAT-DIAG'] > 60, 'LEI60'] = 'Tempo inadequado'

# %%
base.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  TP_CASO      SEXO IDADE LOCAL_NASC RACA_COR  \
# 0           0             0        1  Feminino    50         RJ    Parda
# 1           1             1        1  Feminino    76         MA   Branca
# 2           2             2        1  Feminino    39         RJ   Branca
# 3           3             3        1  Feminino    58         RJ    Preta
# 4           4             4        1  Feminino    44         RN    Parda
#
#              ESCOLARIDADE  CLIN_1_ATEND  CLIN_INICIO_TRAT  ... PERIODO_OBITO  \
# 0    Fundamental completo            15                25  ...             1
# 1  Fundamental incompleto            15                24  ...             1
# 2          Sem informação            15                15  ...             1
# 3          Sem informação            15                15  ...             6
# 4  Fundamental incompleto            15                15  ...             1
#
# ...

# %%
base.to_excel('C:\\Users\\rapha\\Desktop\\Lara\\TCR\\Bases_TCR\lei60.xlsx')

# %%
base.describe()
# Out:
#         Unnamed: 0  Unnamed: 0.1  TP_CASO  CLIN_1_ATEND  CLIN_INICIO_TRAT  \
# count  4120.000000   4120.000000   4120.0   4120.000000       4120.000000
# mean   2059.500000   2059.500000      1.0     15.628641         17.681311
# std    1189.485883   1189.485883      0.0      4.475875         10.846415
# min       0.000000      0.000000      1.0      0.000000          1.000000
# 25%    1029.750000   1029.750000      1.0     15.000000         15.000000
# 50%    2059.500000   2059.500000      1.0     15.000000         15.000000
# 75%    3089.250000   3089.250000      1.0     15.000000         15.000000
# max    4119.000000   4119.000000      1.0     46.000000         99.000000
#
#        ANO_PRIMA_DIAG  ANO_PRIMA_CONS  ANO_INICIO_TRAT      CONS-DIAG  \
# count     4120.000000     4120.000000      4010.000000    4120.000000
# mean      2018.046359     2014.360437      2014.554364     124.007039
# std        175.916323        1.681465         1.749365    2573.683130
# ...
